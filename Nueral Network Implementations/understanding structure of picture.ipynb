# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path = '/content/drive/MyDrive/cropped_images_of_sports_celebirties/Cristiano_Ronaldo/Cristiano_Ronaldo2.png'  # Replace with the path to your image

# %%
img = cv2.imread(image_path,0)

# img = cv2.imread(image_path,0)

# %%
# Alternatively, you can use matplotlib to display the image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
img.shape
# Out:
# (80, 80)

# %%
img.ndim
# Out:
# 2

# %%
img[0][0]
# Out:
# 248
